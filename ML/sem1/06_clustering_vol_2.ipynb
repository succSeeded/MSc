# %%
# %load_ext jupyter_black

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.dummy import DummyClassifier
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Внутренние меры кластеризации
#
# Или как оценивать, если правильных меток не существует в природе?

# %%
features, true_labels = make_blobs(
    n_samples=200, centers=3, cluster_std=2.75, random_state=42
)

kmeans = KMeans(n_clusters=3, n_init=10)
kmeans.fit(features)

## Кстати, кто такой Rand Index ?

print("KMeans Rand Index: ", metrics.rand_score(kmeans.labels_, true_labels))

# %%
## А тут вы сколько ожидаете увидеть? А если пар -- 100? 
random_labels = np.random.randint(0, 3, size=true_labels.shape)
print("Random Rand Index: ", metrics.rand_score(random_labels, true_labels))

# %%
fig, (left, right) = plt.subplots(1, 2)

left.scatter(
    features[:, 0],
    features[:, 1],
    s=15,
    c=random_labels,
)

right.scatter(
    features[:, 0],
    features[:, 1],
    s=15,
    c=kmeans.labels_,
)

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

print(f"Silhouette score")
print(f"random clustering: {silhouette_score(features, random_labels)}")
print(f"kmeans: {silhouette_score(features, kmeans.labels_)}")

print()

print(f"David-Bouldin Index")
print(f"random clustering: {davies_bouldin_score(features, random_labels)}")
print(f"kmeans: {davies_bouldin_score(features, kmeans.labels_)}")

# %% [markdown]
# ---
#
# # Как выбрать число кластеров
#
#
# ### Elbow plot
# Самый простой метод, продолжающий предыдущую тему.
#
# Какое максимальное и минимальное значения $EV$? Как они достигаются?
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/c/cd/DataClustering_ElbowCriterion.JPG" />

# %%
# !pip install yellowbrick
from yellowbrick.cluster import KElbowVisualizer

visualizer = KElbowVisualizer(kmeans, k=(1, 9))

visualizer.fit(features)
visualizer.show()  # тут вместо explained variance сырые расстояния

# %% [markdown]
# ### Silhouette analysis
#
# Выше мы рассмотрели глобальный (усредненный) Silhouette score. Давайте теперь росмотрим на эти коэффициенты, сгруппированные по кластерам

# %%
from yellowbrick.cluster import SilhouetteVisualizer

# поменять число кластеров и посмотркть картинки
model = KMeans(2, random_state=42, n_init=10)
visualizer = SilhouetteVisualizer(model, colors="yellowbrick")

visualizer.fit(features)
visualizer.show()

# %% [markdown]
# ---
#
# ## Case study: сжатие изображений
#
# Адаптация примера из курса К.В. Воронцова.
#
# Преобразуем изображение, приведя все значения
# в интервал [0, 1]: можно использовать функцию `img_as_float` из модуля `skimage`.

# %%
# ! pip install -q --upgrade scikit-image

# %%
import numpy as np

import skimage
from skimage import data, io
from skimage.io import imread, imsave
from sklearn.cluster import KMeans

image = imread("Lenna.png")
print(image.shape, image.max(), image.min())

# %% [markdown]
# Каптинка в т.н. "полноцветном" формате, т.е. по 1 байту на каждый из трех каналов.
#
#  **Сколько всего цветов ?**

# %%
io.imshow(image)

# %% [markdown]
# **PSNR - peak signal-to-noise ratio**
#
# Соотношение между максимумом возможного значения сигнала и мощностью шума, искажающего значения сигнала. Поскольку многие сигналы имеют широкий динамический диапазон, PSNR обычно измеряется в логарифмической шкале в децибелах.
#
# PSNR наиболее часто используется для измерения уровня искажений при сжатии изображений.
#
# $$PSNR = 10 ~ \log_{10} \frac{MAX_{orig}^2}{MSE}$$
#
# Довольно плохая метрика, кстати говоря; как думаете, в чем ее проблема?

# %%
def psnr(X_true, X_clustered):
    
    size =...
    mse = ...
    max_2 = ...
    
    return ...

# %% [markdown]
# Кластеризуем, и все пиксели, отнесенные в один кластер, попробуем заполнить двумя способами: медианным и средним цветом по кластеру. Таким образом мы "сжимаем" изображение.

# %%
float_image = skimage.img_as_float(image, force_copy=True)
float_image.shape,

# %% [markdown]
# Переведём в набор троек RGB

# %%
RGB = ...

RGB.shape, RGB

# %%
import os
os.makedirs('Lenna', exist_ok=True)

clusters = [25] + list(reversed(range(2, 10)))

for n_clusters in clusters:
    
    print(n_clusters, end=" ")
    
    # группируем цвета, которые есть в изображении
    model = KMeans(n_clusters=n_clusters, verbose=False, random_state=100, n_init=10)
    model.fit(RGB)
    X = RGB.copy()
    
    # запоминаем метки кластеров
    labels = model.labels_.T

    for cluster in range(n_clusters):
        
        # по каким индексам в списке пикселей живёт этот кластер?
        ...
        
        # заполняем заполненное средним
        ...
        
    # обратно в трёхмерный вид
    im = ...
    
    print(f"Frobenius norm: {np.linalg.norm(im - float_image):3.2f}" , end=" | ")    
    print(f"PSNR: {psnr(float_image, im):3.3f}" % psnr(float_image, im))
    
    rescaled_im = (im * 255).astype(np.uint8)
    
    # сохраняем
    imsave("Lenna/" + str(n_clusters) + ".png", rescaled_im)

# %%
# image = imread("Lenna/6.png")
# io.imshow(image)

# %%
fig = plt.figure(figsize=(10, 10))
for i, c in enumerate(clusters):
    img = imread(f"Lenna/{c}.png")
    ax = fig.add_subplot(3, 3, i+1)
    ax.title.set_text(f'{c} clusters')
    plt.imshow(img)
plt.show()

# %% [markdown]
# ---
# ## Case study 2: слова

# %%
# ! wget http://vectors.nlpl.eu/repository/20/182.zip
# ! bash -c "unzip -o 182.zip"

# %% [markdown]
# Есть три файла - `meta.json` с метаданными, `lemma.num` с частотами слов и `model.txt` собственно с эмбеддингами.
#
# Давайте кластеризовывать слова на основе их векторных представлений.

# %%
! bash -c "tail -2 model.txt"
# Out:
# человечка_NOUN -0.29234073 0.03835703 0.10110392 -0.27563456 -0.15668419 0.17093626 0.16657482 0.426764 0.05025494 -0.3600553 0.41330293 -0.40945807 -0.1383572 0.18148145 -0.14004365 -0.22425707 -0.02813618 0.12828286 -0.07121982 0.08036167 -0.39346257 0.14418003 -0.112279825 0.050379105 0.65719825 0.28230706 -0.19728823 -0.22937453 -0.37179834 -0.48536462 0.03138419 -0.022372728 -0.07253032 -0.0072454247 0.054911043 0.22537158 0.105023034 0.13699752 0.25621888 -0.1780083 -0.2054968 -0.34535745 0.0049650734 0.3966938 0.08922703 -0.1604564 -0.120386116 -0.08408959 0.33405817 0.15972129 -0.01776049 -0.28450355 -0.34316248 0.08639362 -0.35194418 0.33855405 -0.31983042 0.37213647 0.2329898 0.025947459 0.0820079 -0.3286245 -0.3904638 -0.024789961 -0.21230644 0.5233826 0.37559277 -0.089096 0.0084660575 0.14825182 -0.21078822 0.32954386 0.049764797 -0.063024566 0.06718298 -0.04196897 -0.025229331 -0.35419548 0.22244026 0.08812005 -0.29118997 0.041034646 -0.049780015 0.26969633 0.15984987 0.46960363 0.34548634 0.12669073 0.099294946 -0.12758322 0.19782583 -0.19706145 0.12827785 0.21531309 0.20759009 0.5019985 -0.18518648 0.10265868 0.25719792 0.10807276 0.31383935 -0.16780677 -0.28470233 0.15220934 0.38877803 -0.106540985 -0.08652447 -0.023435544 0.2989956 -0.117616326 -0.09379488 -0.0008618785 -0.018919624 -0.15290576 -0.02281289 -0.15104355 0.23921795 0.16492528 0.14089556 0.102543324 0.24653956 -0.36463594 0.10771394 0.13173835 0.18414749 0.14268476 -0.05099024 0.14705162 -0.06484454 0.047928836 0.5428548 0.2980125 0.1833399 -0.12872188 0.021963075 0.009133721 0.020144649 -0.07686867 0.23092389 0.1456118 -0.003517356 -0.18862323 0.011337296 -0.063626766 -0.09624022 -0.13295133 0.03661496 -0.35044098 -0.09788619 0.36113515 0.02686501 -0.055656914 0.5265834 -0.04782593 -0.14156106 0.25432867 -0.05332989 -0.16091104 0.056619413 -0.06670897 -0.22877713 -0.21731536 0.21417825 -0.20820227 0.27828267 0.17682147 -0.13719305 -0.13945667 0.0054031727 -0.11663324 -0.106976986 0.13662063 0.20222138 0.20810878 -0.06933489 0.13345186 -0.04267266 0.20379746 -0.1594443 0.14188516 -0.31535813 0.06502486 -0.2161278 0.09554597 -0.018459916 0.053035267 0.13947645 -0.19905104 -0.027084412 -0.04359028 -0.036863506 0.3234614 -0.13184375 -0.3990871 0.2616267 0.2555742 0.07972223 -0.62215155 -0.14307258 0.06059609 -0.18984455 0.075966805 0.07191997 -0.42773506 0.0047511156 0.08907646 -0.1079571 0.27497277 -0.18161105 0.0077825985 -0.3215609 -0.074102074 -0.21729736 0.15054496 0.04097672 -0.16368712 -0.14309472 0.06068661 0.0038598466 -0.4420743 0.110311866 0.10124502 0.12671664 0.110006794 -0.19774902 -0.1777014 -0.2553804 0.10277974 -0.0049781995 0.40826666 0.30550915 0.3946043 -0.1604416 -0.20598002 0.038750462 0.19434592 -0.11757204 -0.22548664 0.13802998 0.07502227 0.1658361 -0.09374238 0.1002693 0.09500018 0.0071571716 0.06809795 0.14140742 0.27748427 0.32401052 -0.06623696 -0.050391335 0.14869724 0.28108713 -0.028122416 0.47353512 -0.15660743 -0.19481164 -0.30509636 -0.16675471 -0.055103205 -0.11521389 0.06983374 0.54224104 -0.12157152 -0.0919812 -0.020375531 0.187739 -0.06944927 -0.012957852 0.25232145 -0.29753944 -0.21220694 -0.18231079 -0.42516887 -0.24094391 -0.08955331 0.24479832 -0.012447683 -0.12074216 0.42885143 0.014872796 0.04603342 0.18338427 0.14808649 -0.04833477 -0.1133429 0.039309062 0.06824646 0.14131337 -0.1602637 -0.26807106 -0.14807943 -0.10703891 0.09738719 0.04573076 0.045055028 -0.1682504 -0.19030648 0.1415805 0.53483826
# шнурочек_NOUN -0.33604336 0.017292472 -0.091486074 0.047904253 0.009332563 -0.15515183 0.66737294 0.06135248 0.19160809 -1.7679942e-05 0.17009686 -0.30129194 -0.16181687 0.3417698 0.21780056 -0.0716123 0.33451656 -0.2657784 0.061582193 -0.25252104 -0.2665554 0.15248112 -0.16346785 -0.11819078 0.4071564 0.30247384 -0.2635436 -0.018726427 -0.5252772 -0.32381666 0.21330349 0.30481932 -0.19278763 -0.41886666 0.053605616 0.3777634 -0.004969078 0.023680331 0.18786934 -0.11751599 -0.1606769 -0.38274714 0.3117575 0.48940903 0.40230677 0.025391407 -0.54390997 -0.21230577 0.17432207 0.29847562 0.0435242 -0.11826183 -0.4498725 0.147759 0.25177562 0.07610597 -0.07689369 0.30700278 0.5172007 0.21761346 0.25626904 0.16971175 -0.15220952 0.39193487 -0.07226789 0.28190064 0.34986132 -0.23866397 0.21342734 -0.1752092 -0.022321703 0.3821873 0.07560021 0.06875416 0.18279964 0.29928958 0.09797481 -0.49695915 0.02470462 -0.14763409 -0.25597122 -0.12545136 -0.12077074 0.27788845 0.07181518 0.48233008 0.09578015 -0.25842637 0.06405578 -0.23443204 0.20407993 0.2045301 0.18779583 0.15908378 -0.0036521526 0.17177226 -0.13964313 0.04579801 0.008821564 0.26222593 0.06384117 -0.10579795 0.028162431 0.0015969715 0.24119328 -0.26715747 0.19546491 -0.2492222 0.27658507 -0.17562328 0.08977988 0.34249628 0.038975146 0.14107987 -0.14628358 -0.07264586 0.20779443 -0.12121252 -0.17184122 0.18184447 -0.20813163 -0.07167602 0.06096167 0.32087335 0.15068161 0.13867751 0.05629653 0.08239351 -0.003550489 0.10381576 0.43404827 0.063043416 0.011727771 0.09898939 -0.16344762 -0.07646234 0.2711474 -0.022188837 0.26897854 0.041568045 0.024078358 -0.31012234 0.005279965 -0.40083525 -0.065429464 -0.12768425 0.09322964 -0.13822556 -0.1468467 -0.080493964 -0.03922895 -0.5046661 0.33753714 0.19278848 -0.040640026 -0.10794766 -0.41015399 0.30717856 -0.07061711 -0.05428411 -0.14825039 0.12569024 0.20930077 0.07419202 0.056095034 0.091423675 0.39515817 0.013535358 -0.11164332 -0.09079407 0.044027198 0.04956154 0.31820863 0.06548668 0.14504848 -0.07010672 -0.08917302 0.23643313 -0.37566677 -0.23093463 0.17949168 0.22058038 -0.0821949 0.47867036 0.055542413 0.3711426 0.22266877 0.12214924 0.31817418 0.22427729 0.16999744 0.19336157 0.04681373 -0.22849792 0.17413424 0.10863935 -0.3228858 -0.30972177 -0.1003737 0.095053926 -0.24691384 -0.09240957 0.013398758 -0.39628878 0.08162281 0.26476273 -0.32796022 0.070049234 0.094889715 -0.12955958 -0.19016579 -0.15629554 -0.13849527 0.61516804 -0.23487335 -0.3089972 -0.1618826 0.005182882 -0.0777988 0.20051832 -0.21314447 -0.008509169 0.1836997 -0.08462556 0.061655637 0.03869931 0.20507403 0.110138215 0.17228141 0.46352038 -0.12503344 0.15366864 0.026323391 -0.21975985 -0.094729625 0.32828435 -0.48628035 0.12301107 -0.07644758 0.11225715 0.002778579 -0.16425644 0.44071978 -0.3225117 0.24309985 0.18431205 0.32663712 0.31279492 -0.12699884 0.36163 -0.13607226 0.13740303 0.09435215 0.033263523 -0.12256866 0.03223868 -0.070730664 -0.0001372016 -0.052558813 -0.1950798 -0.24170105 0.24274814 0.16346377 -0.18805014 0.021564534 -0.0053984993 0.08111711 0.15932927 0.35955265 0.18288465 0.14134528 -0.15073243 -0.31644875 -0.26186278 -0.36580297 -0.15297088 0.04998216 0.07750686 -0.1630508 0.3164439 -0.13860193 0.09459045 0.061548173 0.32912463 0.030320086 0.25753954 -0.026032511 0.2337463 0.11722555 -0.085171856 -0.20427401 0.17254667 0.2846307 0.09466832 0.26174304 0.10514171 0.032011706 -0.10110047 0.24950679 0.17947015

# %%
# ! pip install nltk
import nltk
from nltk.corpus import stopwords

nltk.download("stopwords")
STOPS = set(stopwords.words("russian"))
STOPS
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/arabella/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'а',
#  'без',
#  'более',
#  'больше',
#  'будет',
#  'будто',
#  'бы',
#  'был',
#  'была',
#  'были',
#  'было',
#  'быть',
#  'в',
#  'вам',
#  'вас',
#  'вдруг',
#  'ведь',
#  'во',
#  'вот',
#  'впрочем',
#  'все',
#  'всегда',
#  'всего',
#  'всех',
#  'всю',
#  'вы',
#  'где',
#  'да',
#  'даже',
#  'два',
#  'для',
#  'до',
#  'другой',
#  'его',
#  'ее',
#  'ей',
#  'ему',
#  'если',
#  'есть',
#  'еще',
#  'ж',
#  'же',
#  'за',
#  'зачем',
#  'здесь',
#  'и',
#  'из',
#  'или',
#  'им',
#  'иногда',
#  'их',
#  'к',
#  'как',
#  'какая',
#  'какой',
#  'когда',
#  'конечно',
#  'кто',
#  'куда',
#  'ли',
#  'лучше',
#  'между',
#  'меня',
#  'мне',
#  'много',
#  'может',
#  'можно',
#  'мой',
#  'моя',
#  'мы',
#  'на',
#  'над',
#  'надо',
#  'наконец',
#  'нас',
#  'не',
#  'него',
#  'нее',
#  'ней',
#  'нельзя',
#  'нет',
#  'ни',
#  'нибудь',
#  'никогда',
#  'ним',
#  'них',
#  'ничего',
#  'но',
#  'ну',
#  'о',
#  'об',
#  'один',
#  'он',
#  'она',
#  'они',
#  'опять',
#  'от',
#  'перед',
#  'по',
#  'под',
#  'после',
#  'потом',
#  'потому',
#  'почти',
#  'при',
#  'про',
#  'раз',
#  'разве',
#  'с',
#  'сам',
#  'свою',
#  'себе',
#  'себя',
#  'сейчас',
#  'со',
#  'совсем',
#  'так',
#  'такой',
#  'там',
#  'тебя',
#  'тем',
#  'теперь',
#  'то',
#  'тогда',
#  'того',
#  'тоже',
#  'только',
#  'том',
#  'тот',
#  'три',
#  'тут',
#  'ты',
#  'у',
#  'уж',
#  'уже',
#  'хорошо',
#  'хоть',
#  'чего',
#  'чем',
#  'через',
#  'что',
#  'чтоб',
#  'чтобы',
#  'чуть',
#  'эти',
#  'этого',
#  'этой',
#  'этом',
#  'этот',
#  'эту',
#  'я'}

# %%
# выбрасываем стоп-слова
freq_list = ...
len(freq_list)

for i, item in enumerate(freq_list):
    print(item)
    if i == 5:
        break
import numpy as np
from tqdm.notebook import tqdm
# Out:
# криминалист
# грошовый
# золотисто
# ящерка
# четвертый
# комкать

# %%
tokens = []
raw_vectors = []

with open("model.txt", "r+", encoding="utf-8") as rf:

    # пропускаем первую строку
    next(rf)

    for line in tqdm(rf):
        # parse line, extract only vectors corresponding to frequent nouns
        ...


len(tokens), len(raw_vectors)

token2id = {t: i for i, t in enumerate(tokens)}
vectors = np.array(raw_vectors)
# Out:
# 0it [00:00, ?it/s]

# %%
# нормализуем?
vectors = ...

# %%
vectors.shape, vectors.sum(axis=1).shape, vectors.sum(axis=1)
# Out:
# ((16404, 300), (16404,), array([1., 1., 1., ..., 1., 1., 1.]))

# %%
from scipy.spatial.distance import cosine

from scipy.spatial.distance import cosine

king = raw_vectors[token2id["король"]]
queen = raw_vectors[token2id["королева"]]

man = raw_vectors[token2id["мужчина"]]
woman = raw_vectors[token2id["женщина"]]
cosine(king - man, queen - woman)
# Out:
# np.float64(0.23086078526958698)

# %%
from sklearn import cluster

mbk_means = cluster.MiniBatchKMeans(
    n_clusters=70,
    batch_size=1000,
    max_iter=10000,
    n_init=20,
    random_state=100,
    reassignment_ratio=0.1,
)
mbk_means.fit(vectors)

mbk_means.labels_
# Out:
# array([13, 45, 45, ..., 45, 16, 45], dtype=int32)

# %%
tokens2clusters = {t: c for t, c in zip(tokens, mbk_means.labels_)}
cluster2tokens = {l: [] for l in mbk_means.labels_}

# %%
for t, c in tokens2clusters.items():
    cluster2tokens[c].append(t)

for c in sorted(list(cluster2tokens)[:50]):
    print(f"\n>-- Cluster #{c}, {len(cluster2tokens[c])} objects.")
    print(" ".join([w for w in cluster2tokens[c][:100]]))
# Out:
# >-- Cluster #0, 17 objects.
# мастер пояс кисть затылок убор мантия парик прадед жезл привратник рея бицепс скальп подручный чресла зашить поясной
#
# >-- Cluster #1, 208 objects.
# операция удар скорость поверхность соединение клетка спортсмен усилие восстановление обработка частота напряжение травма пластинка поворот ось нагрузка пересечение мышца комбинация электрон равновесие челюсть винт конечность ион облегчение железа сечение стопа анатомия перелом дефект сжатие клавиша сустав кальций вена артерия диаграмма форсирование симметрия хромосома твердость деформация лопасть нокаут матка наклон зубец сварка закрепление позвоночник изгиб жесткость копирование разворот позвонок поршень сцепление фиксация призма нажатие мускул испарение диафрагма ротор кровообращение чешуя отлив коррозия пигмент четкость планер запястье медитация киль визуализация бугорок выравнивание пищевод растворение бороздка антиген неподвижность кровоизлияние транс касание партнерша гортань скольжение стояние крен растяжение натяжение произнесение контузия капилляр выдох спазм
#
# >-- Cluster #2, 42 objects.
# центр поток горизонт вал стадо монумент груда дымок завеса архангел шпиль столп громада безмолвие вышина пелена полчище шлях нагромождение монолит густой тишь махина кипеть ширь гудеть былинка могучий огромность мчаться зависнуть беспредельность доселе тартарары крутить хлябь лесной мга парить навал атлантида бурлить
#
# >-- Cluster #5, 97 objects.
# университет князь губерния император батальон крестьянин губернатор родственник столетие семинария приятель помещик уроженец слушатель кружок преподавание мученик учащийся заключенный прихожанин лакей мещанин усердие юнкер посвящение танцор пансион лектор сослуживец префект библиотекарь юношество хождение швейцар ямщик обет фабрикант старообрядец отшельник санитар конфессия бытность иметь посторонний паж голодовка трущоба клерк дачник репетитор проситель семинарист лавочник акушерка коммунар призывник красногвардеец самообразование маркиза экономка счастливец чад парижанин тюремщик девственница молитвенник геодезист церковник письмоводитель директриса гармонист солдатка безденежье лихач филфак эфиоп стиляга чернец путеец краснофлотец отличница карманник десятиклассник переплетчик мусорщик прибалт заезжий полотер лифтер второгодник старослужащий престижный мореходка учиться восточник уважать патрульный
#
# >-- Cluster #6, 53 objects.
# корабль транспорт побережье радио гарнизон сопровождение отель землетрясение эсминец форт обстрел верфь фут линкор капитуляция корма газопровод подлодка прожектор плот буксир ледокол танкер тральщик субмарина вахта приземление периодичность дрейф мальта форпост носильщик транспортер динамит разрушитель автопилот буревестник ватага армада пароходик регулировщик антей новороссийск аналогичный рафик сыктывкар рыбачка госкомитет универсам агрессивный задевать австрийский титаник
#
# >-- Cluster #7, 153 objects.
# автор память идея успех интерес смысл запись зрение исполнение получение исследователь эффект живопись сомнение сценарист указание бюджет рукопись налог известность эффективность сочетание христианство масштаб восприятие диалог сходство умение претензия симптом символика разногласие отклонение современность присяга мораль коррупция аналогия формулировка самостоятельность реплика трансформация искажение воззрение достоверность трюк издержка отклик компетенция инфляция контраст фантаст задолженность выяснение прочтение тонкость синоним присяжный расхождение преемственность правота ловкость ориентир откровенность уведомление имитация новшество привлекательность колорит оригинальность мягкость утопия апелляция постоянство умысел наивность параграф опубликование нотация несовершенство постулат наследственность новизна выпадение заявитель объективность непрерывность истолкование правдивость аванс живучесть фактура цельность подмена анализатор двойственность веление рентабельность свидетельница гениальность
#
# >-- Cluster #10, 139 objects.
# сентябрь октябрь ноябрь поле слеза престол молитва плод хан племянник апостол превращение простор самбо око клятва царевич влага сияние господь дева суета дзюдо листва ль воскресение сладость роса знамение избавление властитель горесть действо воспитанница думка раздор цвести премудрость боже погибель прибавление воинство называть лоза отрок напасть синева царствие мор аз денек отрада любимый благость томление врать назидание видеть именинник хвала бальзам навек твердь цикада утеха глухо головушка полоть агнец сидячий полубог мзда спас лукаво мириада спасенье крат тать виктория ява кормчий сверкание прожект эка вовек пленить росинка родить благой меркнуть молвить медлить ступать будить паря трижды счастливый отвечать навеки классный
#
# >-- Cluster #11, 53 objects.
# голова дерево планета норма хвост пар плоскость предшественник плавник континент проводник стебель рецептор этюд усик ус гравюра проекция завет судорога подборка свисток пластмасса резец проницаемость извилина лаз скрежет циркуль шестерня препинание покос рыть тик хоботок веретено вязание подлесок тетива модернист наст кесарев колышек носоглотка извив булат скрежетать ошметок певучий окаменеть позвоночный томпсон просек
#
# >-- Cluster #13, 241 objects.
# год участие участник начальник командир деньги уезд сельсовет юг штаб судьба раунд рабочий повод господин еврей русский разрешение казак племя спор княжество начальство раса англичанин знамя нация татарин христианин войско преследование поляк индеец исход эмигрант иностранец обком беженец красноармеец староста армянин обещание итальянец украинец ведомость россиянин католик римлянин трудящийся пленный ходатайство серб брошюра соотечественник артиллерист канцлер британец конница гребец нацист жандарм ничья негр уплата приверженец пехотинец болгарин приказчик азиат поселенец предатель гетто чеченец перс голландец оккупант рапорт протестант жалованье венгр грузин гривна пограничник чех белорус фельдмаршал проигрыш тесть португалец легионер германец масон изменник язычник литовец ирландец доверенность хорват израильтянин земледелец
#
# >-- Cluster #14, 88 objects.
# вопрос институт организация курс встреча очередь разговор врач комиссия специалист контракт назначение фирма заключение занятие интервью просьба заведующий сообщество сектор пациент обслуживание здравоохранение знакомство визит конгресс запрос заявка персонал рекомендация форум переписка предоставление ботаник терапия раскопка надзор обыск санаторий менеджмент экскурсия согласование консультация библиография поликлиника закупка сеанс наставление работодатель настояние демобилизация селекция эфиопия стажировка дебаты психотерапия сотрудница переподготовка бракосочетание стационар допуск оздоровление радиопередача диспансер генетик расспрос вакцинация психотерапевт заверение гинеколог госпитализация стоматолог зам шефство инструктаж главк физиотерапия увещевание дантист клиентура медицинский неотложка прение окулист базель свердловск монтевидео мэри
#
# >-- Cluster #15, 80 objects.
# основа материал влияние поддержка средство способность формирование ресурс механизм установление реконструкция модуль усиление авторитет звено гнездо перемещение опора сталь устойчивость прочность претендент квт надежность перекресток верхушка смещение материк могущество резонанс торможение напор периферия противовес регулятор просвет вертикаль подрыв вибрация сук донор веточка подшипник устой таран оплот коллизия туннель ставленник кормилец лебедка эпицентр зачаток рессора рупор резка блюститель отзвук катапульта подспорье искривление отстаивание дегенерация оттяжка отдушина подпорка сицилия акселератор дворянский внешний соорудить соединить эксплуатировать держаться зависимый провести колесный нагель пролетарский заправить
#
# >-- Cluster #16, 72 objects.
# движение руководство проведение оркестр надежда министерство церемония союзник полуостров согласие единство прекращение завоевание поддержание царствование недовольство совершенствование доблесть устранение одобрение перемирие мобилизация нашествие уступка колонист удержание продление выздоровление дипломатия очищение смута координатор иго напоминание растерянность излечение анархия передел смягчение затишье вытеснение подозрительность депеша включить талиб озлобление космополитизм беспечность выразитель умиротворение самодовольство дискредитация делать ненападение вялость владычица бездеятельность импотенция увядание светоч термидор сполох побеждать облет взойти материальный коварный вглубь обречь попрать завтрашний ослабеть
#
# >-- Cluster #18, 2725 objects.
# фильм слово август май июль апрель июнь территория роль матч земля образование театр помощь совет серия турнир ночь музыка директор дочь звание чемпион литература империя академия тренер событие любовь информация лес провинция футболист спорт герой заместитель футбол счет окончание солдат офицер основание капитан лига руководитель отряд фамилия сцена чувство защита финал растение сотрудник флот тема эпизод север полковник сад студент кино инженер победитель сериал лист небо ученик доллар сообщение сведение передача птица бог восток учитель командование запад открытие представление убийство фестиваль поезд стих ветер ум спектакль слава практика энергия символ солнце флаг лейтенант полиция прием жертва помощник полет администрация телесериал
#
# >-- Cluster #19, 106 objects.
# причина издание волость неделя понятие чин радость проспект продолжение хор мужество риск турок коэффициент видение удовлетворение приближение пират базар братство предотвращение струна благополучие курсант венок мрак земляк писание поляна виноград сдвиг профилактика ласка заросль каюта неправда подсудимый строгость мошенник антисемитизм вексель дикарь аксиома умиление настойчивость спутница ведомо комплимент трезвость дурачок кротость облачко мистика мираж парусник неуверенность терем полька певчий иена хватка плав вожделение отпущение игнорирование одаренность кощунство любознательность опрометью воскреснуть цинга редька сожитель преступница чернокожий целеустремленность придыхание тын волочь горячо меломан бостон зоркость супермен богатей жульничество московит вымогатель скок дискант преосвященство мыслить кикимора лучший афишка мигание родословный метафизик карканье лиходей
#
# >-- Cluster #20, 75 objects.
# название инструмент мультфильм гитара обряд мода кукла призрак палочка приставка узор колокольчик выдумка предрассудок клочок собачка шаман фонарик ожерелье хвостик хобби гармошка крылышко баян малютка балалайка бубен шимпанзе слайд монетка гармонь шпаргалка чудище трель устрашение вертушка прутик колибри горошина бубенчик наподобие кошечка клоунада козленок четки молодожен чертовщина бубенец пустышка ишак погремушка песик отмычка мультик чечетка опоссум шарада выпь закорючка слабак лапта зверюшка божок кощей наседка чертенок наперсток переросток взвизг сосунок павлиний висюлька лютня вить веселить
#
# >-- Cluster #22, 354 objects.
# вечер доктор звук поиск сознание сон счастье воспоминание впечатление сутки боль настроение отдых чудо крик шум ожидание мечта беда смех удивление перерыв восторг страдание тревога еда ненависть подросток скандал молчание графиня нуль уверенность дочка палуба набережная допрос молния завтрак видимость полдень молодец ярость задержка недоумение развалина пристань ловушка сочувствие полночь хаос терпение жажда княжна негодование любовница скамья паника безумие бред отравление утрата супруг откровение вопль быстрота заклинание кошмар ухудшение хохот пена залп припадок прикосновение ураган женитьба рассудок бродяга мучение разлука рефлекс влечение блаженство пьяница аплодисменты лазарет забава пробуждение подлец неудовольствие привидение неспособность нежелание трепет отчуждение выходка обморок затея засуха раскаяние
#
# >-- Cluster #23, 59 objects.
# чемпионат значение знак функция свобода формула сохранение уважение благо идеал совокупность равенство монархия буддизм этика господство индивид общность компромисс вероисповедание суверенитет неравенство дискриминация умножение исчисление налогообложение материализм неприкосновенность святость принуждение взаимопонимание вежливость самоопределение энтропия абстракция равноправие вероучение консенсус феминизм порядочность социализация знаменатель ферзь плюрализм фа интернационализм кантор дружелюбие самосовершенствование подпространство народовластие контра одинаковый фила саморазвитие логик португалия ангола подготовительный
#
# >-- Cluster #24, 68 objects.
# режиссер советник продюсер корона астроном химик изобретатель литератор математик торговец консультант продавец филолог искусствовед промышленник банкир ботаника куратор раввин драгоценность подрядчик технолог первооткрыватель токарь наводчик ювелир грузчик трубач инициал талер мясник металлолом владеть садовод спекулянт прораб педиатр филателист прачка самоучка селекционер резчик металлист слет разносчик богема патологоанатом шарлатан иллюзионист кондитер мещанка ассистентка сварщик эстет кулон водопроводчик портной фальшивомонетчик модистка шорник посыльный эскулап медвежатник стелла скорняк турин альфонс курант
#
# >-- Cluster #26, 34 objects.
# рубль марка торговля мяч книжка близнец бриллиант привет кларнет торт почтальон червонец бычок булка аккордеон булочка пицца гастроном копа пион бублик баянист василек молотилка крендель письмецо гм карамель навар аль арктика колесник автомобильный стариков
#
# >-- Cluster #27, 126 objects.
# область история культура искусство мысль источник происхождение сфера традиция объединение знание ассоциация сотрудничество религия активность человечество утверждение истина ощущение дружба стремление разум мастерство просвещение доверие мышление биология контекст возрождение прогресс верность земледелие последователь археология мудрость меньшинство православие творение добродетель широта величие автономия стихия проповедь закономерность народность преданность канон мировоззрение отрицание эстетика направленность ирония патология нравственность дарование парадокс государственность насаждение самосознание романтизм осознание симпозиум мотивация единение йога этнос профессионализм духовность гуманизм диалектика выносливость иммиграция термодинамика психоанализ остроумие конкурентоспособность терпимость истинность буддист самобытность рефлексия постижение осанка воодушевление самоотверженность тонус почин отождествление первопроходец патогенез ученичество менталитет дикость нигилизм бесстрашие добродушие средоточие сионизм исключительность
#
# >-- Cluster #29, 76 objects.
# действие поражение битва восстание экспедиция сопротивление взрыв колония нападение пожар арест королевство протест захват казнь самоуправление волнение насилие оккупация штурм демонстрация присоединение повстанец подавление ввод митинг разгром изгнание мятеж бунт возведение годовщина теракт забастовка возмущение беспорядок агитация погром мятежник провозглашение расправа декабрист казнить свержение крах геноцид заговорщик резня разорение колонизация роспуск компартия владычество разоблачение истребление отпор феодал вылазка затопление вынесение сожжение разбой авантюра бойня путч облава неповиновение колонизатор зачинщик близ экспроприация вольница экзекуция разослать свергнуть пресечь
#
# >-- Cluster #31, 151 objects.
# деятельность писатель художник должность деятель произведение министр выступление революция секретарь лауреат преподаватель работник лидер историк журналист педагог певец критик чиновник отрасль философ корреспондент коллега переводчик предприниматель ведомство военачальник ректор коммунист сенатор издатель менеджер революционер эмиграция экономист общественность идеология живописец публицист кинорежиссер археолог репутация активист медик выходец геолог репрессия полководец элита теоретик администратор лингвист авангард богослов поэтесса классик биолог знаток коллекционер оратор социолог рейх патриот терминология мыслитель комментатор знаменитость эсер священнослужитель шедевр географ естествознание аристократия поприще журналистка зарубежье сановник политолог альпинист идеолог либерализм функционер натуралист мореплаватель труженик реформатор комик мистик интеллектуал правозащитник просветитель законодатель нападки переводчица бюрократия атташе подвижник гуманист реставратор
#
# >-- Cluster #32, 68 objects.
# сезон роман композитор сборник концерт пьеса опера сочинение диссертация цикл балет консерватория дирижер монография премьера скрипка мюзикл мелодия послание нота трактат солист симфония дубль квартет филармония синтезатор оперетта виолончель романтик саксофон авеню баритон альт мажор соната интернационал контрабас кульминация псалом семестр карнавал гобой кантата идиллия фуга лада опус перекличка созвучие послесловие маэстро исполнить одиссея серенада краснодар фокстрот метроном фанфара менуэт бах мейстерзингер оскар завершить питерский тоника родственный новосибирск
#
# >-- Cluster #33, 166 objects.
# кровь выстрел волк скот мышь молекула дурак лев кот пламя акула жук овца олень пес слон млекопитающее крыса фауна тигр петух обход спичка кролик пальма факел кукуруза комар впадина кинжал лисица вывоз кочевник процессия оса туземец камыш пешка наездник лиса собрат предгорье укус кабан бутерброд вол экватор пыльца овчарка зверек чаща холостяк як крот ковбой лучник просека креветка девчата коралл табун красотка покер дюна хам тетерев сом буйвол спячка чабан родич суслик кальмар пурга писк фазан свастика тролль выгон химера индейка таверна термит лось травинка косуля оказия саванна дележ зевака хомяк овчина благовоние омар питон выть бестия пуща аполлон островитянин
#
# >-- Cluster #34, 1005 objects.
# город война имя число рука команда друг случай женщина род образ семья степень народ жена смерть служба бой брат житель государство правительство душа свет король генерал честь внимание сердце муж девушка пример сестра дух товарищ столица община немец сражение мальчик воля крепость тюрьма крест будущее правда судья обстоятельство обязанность страх вера выбор владение золото сотня святой читатель посол родина долг царство ответственность удовольствие отказ суть соперник наказание обмен американец имение охота адмирал подруга сожаление уничтожение покой намерение бомба подарок королева императрица совесть голод плата вступление вероятность боярин горе княгиня благодарность живот дар розыгрыш покупка пророк осада рана держава взятие красавица
#
# >-- Cluster #37, 91 objects.
# страница отдел парк вещество дождь препарат шутка куст зерно кафе яблоко аптека цветение грипп конфета иероглиф благородие цент вишня словечко паста пряность конопля тир гирлянда стебелек персик обрамление осока отвар можжевельник горчица антидепрессант махорка кабачок петрушка кофейня листик санитарка саженец джин славка нега оборванец мартышка шевелюра понос су вертеп черешня цветной гуляние желчь лилипут ежевика морфий квинтэссенция тюрбан коррида фанк уродец псков присесть вереск сазан шарманщик бывать гипербола сказочка пук ночка опий курортник ксерокс лютик чаек авитаминоз чернуха светляк кончать абракадабра странно цитировать лан неаполь аконит мадрид обрывать недотрога пестреть венгерский
#
# >-- Cluster #38, 105 objects.
# завод промышленность газ порт тонна фабрика труба добыча цех боеприпас переработка энергетика трактор магистраль экономия электроэнергия генератор агрегат электроника терминал порошок азот заготовка металлургия турбина бензин железнодорожный тепловоз шахтер смола уран мох полимер катализатор никель трансформатор цемент аммиак крошка нефтепродукт автотранспорт орошение разлив банан печенье подстанция кубометр метан концентрат сырой запчасть сжигание стройматериал ворох сенокос стружка лесозаготовка полуфабрикат фитиль ломтик войлок фугас щепа плавка батон жечь печник индий вар летучка килька чипсы зил блинчик брикет силос общепит формалин халва головня сардина костерок грунтовка крекинг гута пакля масленок бензовоз мороженый высушивание грейдер жмых лапник тальк шеллак копать зав технический скирд присыпка
#
# >-- Cluster #39, 402 objects.
# дело сын орден минута море царь канал ответ желание крыло полоса волос губа нос снег ужас улыбка колесо колонна внук пятно лоб воевода перо бас авария луг мальчишка барабан гордость рассвет схватка покров полюс пустота муха сумерки девчонка очаг шофер плоть поклон бант кишка нежность жар вздох клюв произношение грусть мачта гул прохожий фокус ноздря кучка шип коготь лапка баржа усмешка занавес висок паутина копыто дамба кулиса шрам ордер воробей шорох парочка чутье клок пешеход брызги рыдание гудок болтовня косяк полумесяц солдатик косой скула ругательство тихий опор черед секреция злой ниточка покрывало исподлобья бедняга корешок обидчик украдкой мускулатура пациентка зарево
#
# >-- Cluster #40, 185 objects.
# период проблема борьба структура применение отсутствие волна явление конфликт реакция признак увеличение воздействие смена понимание падение расширение фон введение десятилетие сокращение возникновение потенциал повреждение распад фаза концентрация эволюция вторжение колебание отбор противоречие выделение уменьшение размещение спектр отмена затрата регулирование обновление приступ становление взаимоотношение монтаж баланс вспышка шкала депрессия упадок стабильность передвижение бомбардировка интенсивность расцвет преступность недостаточность противодействие реорганизация чувствительность восхождение накопление дефицит нехватка примесь предпосылка наводнение прирост смертность агрессия напряженность стабилизация трение избежание аббревиатура спад преобладание потрясение шок путаница неопределенность горение перегрузка экспансия созревание ответвление возбудитель зародыш перепад старение рождаемость зарождение непонимание отключение сосредоточение дифференциация уклонение заинтересованность преувеличение замедление охват
#
# >-- Cluster #42, 56 objects.
# язык песня мнение речь рассказ перевод выражение термин надпись сказка фраза очерк прозвище обычай промысел летопись высказывание теорема цитата кличка лад наречие пословица карикатура поговорка стереотип сплетня словосочетание басня вольность афоризм лексикон уловка сценка поверье ерш сказ худо фикция сентенция междометие знахарь фразеология эвфемизм кроссворд присказка самокрутка свояк баста самоучитель окрошка рассказывать русски пошехонец талмуд ахти
#
# >-- Cluster #43, 12 objects.
# перепись сеть запас богатство сено сбыт нива запасник делянка закром открытый создавать
#
# >-- Cluster #44, 117 objects.
# комната стол окно пол доска колено кухня кресло стул госпиталь постель кровать лавка потолок диван подушка ковер шкаф спальня скамейка одеяло сиденье койка спинка рояль седло буфет перегородка подоконник купе горница скатерть пианино простыня парта нары занавеска корточки носилки сумочка табуретка штора перекладина матрац новорожденный табурет ширма кушетка помост уборщица чулан изголовье четвереньки люлька портьера кроватка плед крылечко храп диванчик перина тахта пролетка сверток ручонка шторка роженица кубрик будуар тюфяк циновка лежанка топчан комнатушка матрас обнимка психушка балдахин дрожать верстак предбанник стульчик всхлип домкрат аврора софа чум приемный нищенка кряхтеть шезлонг врачиха турник чурбан стелька хрипеть лаборантка скрепка постелька портмоне
#
# >-- Cluster #45, 6885 objects.
# человек время район место состав часть работа жизнь мир река группа игра век километр вид деревня население член сторона дом страна конец система начало сайт школа сила село пункт метр лицо округ клуб ребенок наука глаз право поселение отношение альбом качество вода тысяча отец дорога церковь связь развитие станция площадь форма путь ряд премия управление остров уровень цель количество тип состояние возможность дивизия край течение момент программа фронт линия мужчина класс процесс производство создание условие труд голос исследование положение карьера ход мать миллион тело представитель медаль граница объект корпус нога полк закон длина штат глава машина возраст высота пора строительство
#
# >-- Cluster #46, 25 objects.
# партия проект орган техникум дворянство интеллигенция гастроль поставщик горком мафия казах депортация латыш парковка перераспределение оргкомитет парторганизация филантроп федерализм сбить замполит программка табачник днепропетровск пионерский
#
# >-- Cluster #47, 105 objects.
# суд комитет факт учреждение попытка брак содержание созыв доход преступление исполнитель обвинение полномочие осуществление подробность показание сделка отступление поступление прогноз штраф заработок инстанция интрига отправление репортаж произвол выигрыш безработица иммигрант жалование пьянство арестант обвиняемый клевета несправедливость правонарушение слушание извинение изнасилование ответчик подлость сговор проституция контрабанда каста неизвестность вождение обвинитель отстранение прецедент трата абзац побои наркомания опала выселение бунтовщик задаток экстремизм сокрытие лесбиянка сектант мести коварство махинация подкуп психопат происки неуважение гомосексуализм упущение алиби таймс малодушие навет нравоучение воровка клеветник безнаказанность обыденность делишки неустойка тунеядец худший отступник констатация дознаватель глумление психопатия стрелочник лгун участковый дедовщина невезение садизм изувер неуместность венгрия краденый
#
# >-- Cluster #48, 41 objects.
# природа действительность диалект бытие тоска говор средневековье субстанция штрих метать лень панк чуждый быстрый ностальгия аура шипение глухой дуновение мерцание лязг идиотизм гомон немота благодушие ментальность шевеление четкий робкий тусклый урчание какофония крепнуть жгучий хрипотца тысячелетний видимый настроить ожидать ощутимый тревожный
#
# >-- Cluster #49, 94 objects.
# компания газета предприятие рынок банк фонд пассажир посольство гостиница ресторан интернет кинофестиваль пресса комбинат реклама совхоз корпорация туризм депо такси выплата инвестор акционер консульство спецслужба зоопарк медиа банкротство концерн корт абонент гонорар олигарх кинокомпания кредитование казначейство арендатор телепрограмма дилер горисполком универмаг провайдер регистратор гид эколог пансионат энергетик кабаре периодика автозавод инвестирование мясокомбинат пединститут экспортер пту автостоянка спортзал торонто деканат завуч абонемент харчевня сантехник фифа спецшкола автоколонна угонщик портье золотоискатель нелегал аозт разнорабочий нерезидент лукойл ммм водник барселона областной медосмотр турфирма дочерний корея отгул фсб сбербанк владивосток пассажирский якутия боинг центробанк ставрополь автоцентр цб перерастать
#
# >-- Cluster #50, 37 objects.
# победа граф супруга государь сей добро отечество сокровище дань град православный малый обретение вельможа лавра счастие позволение асессор ваш дотоле самодержец великий толь матерь посвятить разный общий кондак рао скрыть правоверный россия субботний исполнять немалый иман касаться
#
# >-- Cluster #52, 53 objects.
# монастырь библиотека дворец архитектор больница аэропорт переулок наследник квартал метрополитен мечеть вдова женатый канцелярия стража посланник гавань мемориал разъезд святыня закладка диаспора подворье снос опекун трапеза эрмитаж венчание посад государев неподалеку почтамт читальня домработница объезд зверинец райсовет ломбард сожительница маслозавод тольятти складчина москва освятить младой украина женский киото мельбурн воздвигнуть становой сокольник абакан
#
# >-- Cluster #53, 10 objects.
# шаг секунда премьер шанс марш плацдарм размах урон мах замах
#
# >-- Cluster #54, 199 objects.
# улица берег здание поселок двор храм зал мост башня площадка долина этаж шоссе крыша городок коридор луна вертолет посетитель фасад офис столб катер костер часовня тоннель бухта аллея цирк бар арка курорт сквер рай павильон балкон общежитие тропа сторож терраса тротуар подножие колхозник трактир мостик подполье вестибюль костел перевал шлюпка чердак тундра вышка хижина островок укрытие котловина бугор вывеска навес холл карниз шлюз ограждение подземелье беседка утес сугроб веранда садик манеж киоск причал цыпочки перрон газон усыпальница трюм дворик оранжерея бомбежка шалаш макушка питомник ангар прохлада лужайка фойе фронтон качели грядка заморозка балаган застолье пикник галька эстакада изгородь стайка далее
#
# >-- Cluster #56, 81 objects.
# статья версия текст статистика вывод публикация следствие наследие свидетельство доказательство последовательность современник аспект логика гипотеза синтез рецензия прототип аналог составление тематика оригинал экранизация интерпретация суждение изложение феномен толкование обоснование примечание авторство совпадение обобщение параллель трактовка изыскание улика сводка юриспруденция домна пробел противопоставление опровержение подлинник осмысление метрика пояснение допущение вымысел первоисточник нюанс пересказ плагиат делопроизводство калькулятор предыстория информатор умозаключение множественность топография мироощущение кода эмоциональность правдоподобие апокриф дешифровка перепечатка ошибочность оглавление ноосфера перевести мк цикличность правдивый утерять оригинальный авторский ложный аналитика рукописный атомный
#
# >-- Cluster #57, 21 objects.
# март итог подготовка рамка наступление завершение дебют юбилей провал альянс разгар преддверие триумф воссоединение предтеча канун полугодие бойкот летие дебютный латвия
#
# >-- Cluster #58, 24 objects.
# профессор актер персонаж волейбол бизнесмен космонавт пародия литературовед киноактер теннисист психиатр кумир музыковед психоаналитик грамзапись спринтер сыграть вундеркинд киномеханик дважды вояка замужем дорогуша запевала
#
# >-- Cluster #59, 185 objects.
# армия власть общество игрок политика поэт ученый союз эпоха агент правитель публика боец сторонник психология страсть зло преступник юрист убеждение вождь борец переворот трон террорист профсоюз симпатия противостояние хирург журналистика социология шах гонщик ополчение буржуазия секта маг знать кинематографист крестьянство позор проклятие анархист сатира полемика репортер зомби вражда жадность единомышленник жид свалка возглас соперничество алкоголизм наклонность разврат издевательство алкоголик реванш инквизиция абсурд романист почитатель жулик диверсант демонстрант посягательство деспот уголовник делец клика фокусник сепаратист спартанец фанатизм пролетарий бей прозвание мечтатель бездельник афинянин астролог хакер шантаж тирания автомобилист выкрик комдив деспотизм апатия лесть вранье продолжатель обманщик козни царизм газетчик порицание сыск
#
# >-- Cluster #61, 172 objects.
# книга решение журнал письмо план документ реестр кандидат приказ обеспечение требование предложение подразделение соглашение печать распоряжение постановление заявление деталь собственность доклад имущество ценность расход раздел концепция принятие приложение грамота вуз цифра законодательство проверка бюро файл упоминание дневник учебник подпись лицензия оформление справочник написание обязательство кодекс замечание инструкция аспирантура справка гражданство референдум страхование законопроект подписание резолюция рф бумажка заказчик гарантия завещание мандат собственник тетрадь документация платеж прошение указатель мемуар санкция исполком табличка декларация методология посылка эссе льгота декрет удостоверение договоренность пошлина разбирательство опись хронология отчетность переименование автобиография донос курьер повестка должник норматив вложение взыскание корреспонденция таможня госбезопасность анкета фальсификация налогоплательщик реликвия
#
# >-- Cluster #62, 61 objects.
# день январь декабрь февраль час месяц утро праздник заседание воскресенье прогулка суббота заря полчаса понедельник навигация выходной ночлег гостья панихида завтра солнышко минутка именины гулянье приятельница обедня молебен масленица бдение семейка дремота неделька разок минуточка вечерок получка газетка тибет утренний зорька всласть позвонить штукатур отдохнуть рань дневной прополка утречко переменка картишки прилететь прилечь послушать просиживать ртр поторопиться телек десятиклассница золотарь подмосковный
#
# >-- Cluster #63, 39 objects.
# результат вариант красота расположение замена точность методика простота склонность случайность целостность искренность стойкость законность правильность целесообразность несогласие конструирование манипуляция погрешность своеобразие усвоение изящество корректировка несостоятельность беспомощность недопустимость стройность успеваемость очередность доведение сообразительность оперативность бестактность незыблемость осмотрительность обратный неповторимость насчет
#
# >-- Cluster #66, 28 objects.
# композиция творчество фрагмент вокал хит полотно иллюстрация звучание сплав регистр гармония повторение орнамент стилистика интеграл придание выразительность заставка расщепление припев повтор пластичность мандолина драматизм ударный ремарка комплексный отличный
#
# >-- Cluster #68, 81 objects.
# теория технология мозг атмосфера смесь труп поручение излучение клиника сырье слог трансляция фермент прозаик сближение четверг тэц лепесток извлечение смешение пойма гибрид эхо созерцание азербайджанец торф регуляция мгла банкет головоломка сумрак расставание чело сочинитель расизм фонограмма талисман сдержанность вырезка пальба распря существительное зигзаг саботаж сперма заботливость агентура мошка прерогатива диссонанс излияние пайщик антиквариат диспозиция мотылек лосось неудовлетворенность сонм пенициллин бесстыдство кроткий полусон супостат ракетчик адвентист громила тунеядство мытарь осинка галиматья нелепица закаливание извлечь побудка страшный сотрапезник политинформация щелканье вначале влачить отбивать

# %% [markdown]
# ### Задание со звездочкой 17. Dunn index
# Реализуйте Dunn Index. Будет засчитываться не абы-какая реализация, а соответствующая по стилю и оформлению реализации метрик в sklearn: обязательны докстринги, валидаторы и все такое.
#
# То, как реализованы другие метрики, можно посмотреть [тут](https://github.com/scikit-learn/scikit-learn/blob/main/sklearn/metrics/cluster/_unsupervised.py#L195).

# %% [markdown]
# ### Задание со звездочкой 18. Topic Modelling via naive clusterization
#
# Мы использовали какой-то простейший метод кластеризации. На лекциях вам рассказывали еще о нескольких из них. Возьмите парочку других, прокомментировав свой выбор. Примените к тем же данным, выберете (аргументировано!) число кластеров и сравните модели между собой с помошью внутренних мер кластеризации.

# %%
from sklearn.utils._param_validation import (
    validate_params,
)

@validate_params(...)
def dunn_score(...):
    """
    Compute the Dunn Index by given within-cluster distances (callable or precomputed) and
    between-cluster distances(callable or precomputed).
    ...
    
    """
    ...
    return
